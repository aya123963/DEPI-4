# %%
class SentenceSplitter:
    """
    SentenceSplitter class handles the operation of splitting
    a sentence into a list of words.

    Attributes:
    sentence (str): The sentence to be split.
    """

    def __init__(self, sentence):
        """
        Initializes the SentenceSplitter with a sentence.

        Parameters:
        sentence (str): The sentence entered by the user.
        """
        self.sentence = sentence

    def split_sentence(self):
        """
        Splits the sentence into a list of words.

        Returns:
        list: A list of words from the sentence.
        """
        words_list = self.sentence.split()
        return words_list


# Test the class
sentence = input("Enter a sentence: ")
splitter = SentenceSplitter(sentence)
result = splitter.split_sentence()
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>
